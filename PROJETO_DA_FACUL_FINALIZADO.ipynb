# %% [markdown]
# <a href="https://colab.research.google.com/github/Luiz-Fernando06/projeto-da-faculdade/blob/main/PROJETO_DA_FACUL_FINALIZADO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#BIBLIOTECAS................................................................................
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
from sklearn import svm

#CLASSIFICADOR..............................................................................
df = pd.read_csv('medico_db_TotalemnteTratado.csv')

X = df[['IdMedico', 'tip_urgencia', 'tip_acomod', 'tipo_cirurgia']]
y = df['tecnica']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
clf = DecisionTreeClassifier(random_state=1)
clf2 = svm.SVC()

clf.fit(X_train, y_train)
clf2.fit(X_train, y_train)

#MENU.......................................................................................
def menu():
 print(" Digite: ")
 print('   1 - Para Classificador com Árvore Decisão')
 print('   2 - Para Classificador com SVM')
 print('   3 - Para sair')

#ARVORE.....................................................................................
def menu_arvore():
  print('ÁRVORE DE DECISÂO: ')
  print('   1 - Mostrar desempenho')
  print('   2 - Mostrar desenho da árvore')
  print('   3 - Fazer nova classificação')
  print('   4 - Voltar ao menu')

def desempenho_arvore():
 y_pred = clf.predict(X_test)
 acuracia = accuracy_score(y_test, y_pred)
 print("Desempenho:", acuracia)

def desenho_arvore():
 data_colunas_uteis = ['IdMedico', 'tip_urgencia', 'tip_acomod', 'tipo_cirurgia']
 data_class_names = ['0','1']
 tree.plot_tree(clf, feature_names = data_colunas_uteis,class_names= data_class_names, filled = True)
 plt.show()

def nova_classificacao():
 entrada_dicionario = {'IdMedico': int(input('Id Medico(1 até 721): ')),
            'tip_urgencia': float(input('Tipo de Urgencia(0: não urgente ou 1: urgente): ')),
            'tipo_cirurgia': int(input('Tipo de Cirugia (0: Cirurgia oncológica, 1: Apendicectomia, 2: Colecistectomia, 3: Hérnia inguinal, 4: Lipoaspiração estética, 5: Cirurgia emergencial abdominal): ')),
            'tip_acomod': int(input('Tipo de acomodação(1: Acomodação Comum ou 2: Acomodação de Emergencia): ')),
            }
 entrada = pd.DataFrame([entrada_dicionario],  columns=['IdMedico', 'tip_urgencia', 'tip_acomod', 'tipo_cirurgia'])
 pred = clf.predict(entrada)
 if pred == 1:
  print('Técnica usada: PADRÃO (cirurgia aberta)')
 else:
  print('Técnica usada: VIDEOLAPAROSCOPIA')

#SVM........................................................................................
def menu_svm():
  print('SVM: ')
  print('   1 - Mostrar desempenho')
  print('   2 - Fazer nova classificação')
  print('   3 - Voltar ao menu')

def desempenho_svm():
 y_pred = clf2.predict(X_test)
 acuracia = accuracy_score(y_test, y_pred)
 print("Desempenho:", acuracia)

def nova_classificacao_svm():
 entrada_dicionario = {'IdMedico': int(input('Id Medico(1 até 721): ')),
            'tip_urgencia': float(input('Tipo de Urgencia(0: não urgente ou 1: urgente): ')),
            'tipo_cirurgia': int(input('Tipo de Cirugia (0: Cirurgia oncológica, 1: Apendicectomia, 2: Colecistectomia, 3: Hérnia inguinal, 4: Lipoaspiração estética, 5: Cirurgia emergencial abdominal): ')),
            'tip_acomod': int(input('Tipo de acomodação(1: Acomodação Comum ou 2: Acomodação de Emergencia): ')),
            }
 entrada = pd.DataFrame([entrada_dicionario],  columns=['IdMedico', 'tip_urgencia', 'tip_acomod', 'tipo_cirurgia'])
 pred = clf2.predict(entrada)
 if pred == 1:
  print('Técnica usada: PADRÃO (cirurgia aberta)')
 else:
  print('Técnica usada: VIDEOLAPAROSCOPIA')

#ESCOLHAS...................................................................................
while True:
  print('Classificador de técnicas medicas')
  menu()
  escolha = int(input('Escolha uma opção: '))
  if escolha == 1:
    while True:
     menu_arvore()
     escolha = int(input('Escolha uma opção: '))
     if escolha == 1:
      desempenho_arvore()
     elif escolha == 2:
      desenho_arvore()
     elif escolha == 3:
      nova_classificacao()
     elif escolha == 4:
      break
     else:
      print('Opção inválida')
  elif escolha == 2:
    while True:
      menu_svm()
      escolha_svm = int(input('Escolha uma opção: '))
      if escolha_svm == 1:
        desempenho_svm()
      elif escolha_svm == 2:
        nova_classificacao_svm()
      elif escolha_svm == 3:
        break
      else:3
      print('Opção inválida')
  elif escolha == 3:
    print('Saindo...')
    break
  else:
    print('Opção inválida')
# Out:
# Classificador de técnicas medicas
#  Digite:
#    1 - Para Classificador com Árvore Decisão
#    2 - Para Classificador com SVM
#    3 - Para sair
# Escolha uma opção: 2
# SVM:
#    1 - Mostrar desempenho
#    2 - Fazer nova classificação
#    3 - Voltar ao menu
# Escolha uma opção: 2
# Id Medico(1 até 721): 551
# Tipo de Urgencia(0: não urgente ou 1: urgente): 1
# Tipo de Cirugia (0: Cirurgia oncológica, 1: Apendicectomia, 2: Colecistectomia, 3: Hérnia inguinal, 4: Lipoaspiração estética, 5: Cirurgia emergencial abdominal): 2
# Tipo de acomodação(1: Acomodação Comum ou 2: Acomodação de Emergencia): 1
# Técnica usada: PADRÃO (cirurgia aberta)
# Opção inválida
# SVM:
#    1 - Mostrar desempenho
#    2 - Fazer nova classificação
#    3 - Voltar ao menu
# Escolha uma opção: 3
# Classificador de técnicas medicas
#  Digite:
#    1 - Para Classificador com Árvore Decisão
#    2 - Para Classificador com SVM
#    3 - Para sair
# Escolha uma opção: 1
# ÁRVORE DE DECISÂO:
#    1 - Mostrar desempenho
#    2 - Mostrar desenho da árvore
#    3 - Fazer nova classificação
#    4 - Voltar ao menu
# Escolha uma opção: 3
# Id Medico(1 até 721): 551
# Tipo de Urgencia(0: não urgente ou 1: urgente): 1
# Tipo de Cirugia (0: Cirurgia oncológica, 1: Apendicectomia, 2: Colecistectomia, 3: Hérnia inguinal, 4: Lipoaspiração estética, 5: Cirurgia emergencial abdominal): 2
# Tipo de acomodação(1: Acomodação Comum ou 2: Acomodação de Emergencia): 1
# Técnica usada: PADRÃO (cirurgia aberta)
# ÁRVORE DE DECISÂO:
#    1 - Mostrar desempenho
#    2 - Mostrar desenho da árvore
#    3 - Fazer nova classificação
#    4 - Voltar ao menu
# Escolha uma opção: 4
# Classificador de técnicas medicas
#  Digite:
#    1 - Para Classificador com Árvore Decisão
#    2 - Para Classificador com SVM
#    3 - Para sair
# Escolha uma opção: 3
# Saindo...

# %%
df = pd.read_csv('medico_db_TotalemnteTratado.csv')
df.tail(50)
# Out:
#      IdMedico  tip_urgencia  tecnica  tipo_cirurgia  tip_acomod  ano_cirurg  \
# 197       437           0.0      1.0              0           1        2020
# 198       437           0.0      1.0              1           1        2020
# 199       494           0.0      1.0              2           2        2020
# 200       193           0.0      1.0              2           2        2020
# 201       515           0.0      1.0              1           2        2020
# 202       406           1.0      1.0              1           2        2020
# 203       406           1.0      1.0              0           1        2020
# 204       537           1.0      1.0              5           2        2020
# 205        32           0.0      2.0              4           1        2020
# 206        32           0.0      1.0              4           2        2020
# 207        32           0.0      1.0              4           1        2020
# 208       565           0.0      1.0              0           2        2020
# 209       565           0.0      1.0              5           1        2020
# 210       283           0.0      1.0              4           2        2020
# 211       318           0.0      1.0              0           1        2020
# 212       549           0.0      1.0              4           1        2020
# 213       318           0.0      1.0              0           2        2020
# 214       492           0.0      1.0              4           2        2020
# 215       318           0.0      1.0              5           2        2020
# 216       406           0.0      2.0              0           1        2020
# 217        32           0.0      1.0              4           1        2020
# 218       406           0.0      1.0              0           1        2020
# 219       391           1.0      1.0              4           1        2020
# 220       391           0.0      1.0              1           2        2020
# 221       391           0.0      1.0              4           1        2020
# 222       623           1.0      1.0              3           2        2020
# 223       674           0.0      2.0              0           1        2020
# 224       521           0.0      1.0              0           1        2020
# 225       521           0.0      1.0              5           1        2020
# 226       565           0.0      1.0              5           2        2020
# 227       452           0.0      1.0              2           2        2020
# 228       452           0.0      1.0              4           2        2020
# 229       452           0.0      1.0              4           2        2020
# 230       383           0.0      1.0              0           1        2020
# 231       383           1.0      1.0              0           1        2020
# 232       374           0.0      1.0              3           3        2020
# 233       351           0.0      2.0              1           2        2020
# 234       383           0.0      1.0              1           2        2020
# 235       383           0.0      1.0              2           2        2020
# 236       383           0.0      1.0              0           2        2020
# 237       383           0.0      1.0              4           2        2020
# 238       383           0.0      1.0              4           2        2020
# 239       521           0.0      1.0              0           1        2020
# 240       551           1.0      2.0              2           1        2020
# 241        23           0.0      1.0              0           2        2020
# 242       610           0.0      1.0              4           1        2020
# 243       369           0.0      1.0              4           2        2020
# 244       406           1.0      1.0              0           1        2020
# 245       684           0.0      2.0              5           1        2019
# 246       316           1.0      1.0              1           2        2019
#
#      mes_cirurg  dia_semana_cirurg  ano_cadastro  mes_cadastro  \
# 197           3                  3          2020             3
# 198           3                  3          2020             3
# 199           3                  0          2020             3
# 200           2                  3          2020             3
# 201           3                  5          2020             3
# 202           3                  6          2020             3
# 203           3                  6          2020             3
# 204           3                  3          2020             3
# 205           3                  2          2020             3
# 206           3                  4          2020             3
# 207           3                  3          2020             3
# 208           3                  4          2020             3
# 209           3                  2          2020             3
# 210           3                  2          2020             3
# 211           3                  1          2020             3
# 212           3                  4          2020             3
# 213           3                  1          2020             3
# 214           3                  2          2020             3
# 215           3                  2          2020             3
# 216           3                  0          2020             3
# 217           3                  0          2020             3
# 218           3                  0          2020             3
# 219           2                  6          2020             3
# 220           2                  0          2020             3
# 221           2                  3          2020             3
# 222           1                  2          2020             3
# 223           3                  2          2020             3
# 224           3                  1          2020             3
# 225           3                  1          2020             3
# 226           3                  0          2020             3
# 227           3                  3          2020             3
# 228           3                  3          2020             3
# 229           3                  3          2020             3
# 230           3                  5          2020             3
# 231           3                  4          2020             3
# 232           3                  1          2020             3
# 233           3                  3          2020             3
# 234           3                  5          2020             3
# 235           3                  5          2020             3
# 236           3                  2          2020             3
# 237           3                  4          2020             3
# 238           3                  1          2020             3
# 239           3                  1          2020             3
# 240           3                  4          2020             4
# 241           3                  4          2020             4
# 242           2                  3          2020             4
# 243           3                  0          2020             4
# 244           4                  3          2020             4
# 245          12                  4          2020             4
# 246          12                  5          2020             4
#
#      dia_semana_cadastro  hora_inicio_hora  hora_fim_hora
# 197                    5              15.0             16
# 198                    5               7.0              8
# 199                    5               0.0              0
# 200                    5              18.0             21
# 201                    5               8.0             10
# 202                    6               2.0              3
# 203                    6               9.0             10
# 204                    6              14.0             17
# 205                    6              18.0             18
# 206                    6               9.0             10
# 207                    6              17.0             18
# 208                    6               9.0             11
# 209                    6               0.0             17
# 210                    6               0.0              0
# 211                    0               9.0             10
# 212                    0              10.0             11
# 213                    0              13.0             13
# 214                    0               9.0             10
# 215                    0              14.0             17
# 216                    0              11.0             12
# 217                    0              10.0             12
# 218                    0              15.0             17
# 219                    0              15.0             16
# 220                    0               8.0              9
# 221                    0              13.0             14
# 222                    0               9.0             10
# 223                    0              15.0             16
# 224                    0              14.0             15
# 225                    0              12.0             13
# 226                    0               0.0              0
# 227                    1              14.0             16
# 228                    1              15.0             17
# 229                    1              21.0             22
# 230                    1               8.0              8
# 231                    1              17.0             18
# 232                    1              10.0             11
# 233                    1               7.0              9
# 234                    1              10.0             11
# 235                    1               9.0              9
# 236                    1              14.0             16
# 237                    1               9.0             11
# 238                    1              13.0             15
# 239                    1              21.0             22
# 240                    2              16.0             17
# 241                    2              11.0             12
# 242                    2              10.0             11
# 243                    3              16.0             17
# 244                    3               6.0              7
# 245                    3              14.0             16
# 246                    3              16.0             17
